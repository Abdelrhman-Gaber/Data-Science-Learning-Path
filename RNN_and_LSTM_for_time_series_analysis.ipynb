# %% [markdown]
# # RNN and LSTM for time series analysis
# **Import Libraries**

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from fbprophet import Prophet
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import MinMaxScaler

import datetime
from datetime import date
import random

# %% [markdown]
# **Import Data**

# %%
data = pd.read_csv('Metro_Interstate_Traffic_Volume.csv', infer_datetime_format=True)

# %%
data.head()
# Out:
#   holiday    temp  ...            date_time  traffic_volume
# 0    None  288.28  ...  2012-10-02 09:00:00            5545
# 1    None  289.36  ...  2012-10-02 10:00:00            4516
# 2    None  289.58  ...  2012-10-02 11:00:00            4767
# 3    None  290.13  ...  2012-10-02 12:00:00            5026
# 4    None  291.14  ...  2012-10-02 13:00:00            4918
#
# [5 rows x 9 columns]

# %%
data['date_time'] =  pd.to_datetime(data['date_time'], format='%Y-%m-%d %H:%M:%S')

# %%
data = data.set_index(pd.DatetimeIndex(data['date_time']))

# %%
ts = data['2018-03-30':'2018-09-29']

# %%
ts.head()
# Out:
#                     holiday    temp  ...           date_time  traffic_volume
# date_time                            ...
# 2018-03-30 00:00:00    None  272.30  ... 2018-03-30 00:00:00             817
# 2018-03-30 01:00:00    None  271.93  ... 2018-03-30 01:00:00             413
# 2018-03-30 02:00:00    None  271.22  ... 2018-03-30 02:00:00             329
# 2018-03-30 03:00:00    None  270.09  ... 2018-03-30 03:00:00             359
# 2018-03-30 04:00:00    None  269.65  ... 2018-03-30 04:00:00             749
#
# [5 rows x 9 columns]

# %% [markdown]
# Train/Test Split

# %%
#Credit: Adopted from https://machinelearningmastery.com/convert-time-series-supervised-learning-problem-python/
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    dff = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(dff.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(dff.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
values = pd.DataFrame(ts.traffic_volume.values).set_index(pd.DatetimeIndex(ts['date_time']))

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = pd.DataFrame(scaler.fit_transform(values)).set_index(pd.DatetimeIndex(ts['date_time']))
# frame as supervised learning
reframed = series_to_supervised(scaled, 24, 1)

# %%
reframed.head()
# Out:
#                      var1(t-24)  var1(t-23)  ...  var1(t-1)   var1(t)
# date_time                                    ...
# 2018-03-30 23:00:00    0.094308    0.037100  ...   0.312518  0.217219
# 2018-03-31 00:00:00    0.037100    0.025205  ...   0.217219  0.114982
# 2018-03-31 00:00:00    0.025205    0.029453  ...   0.114982  0.114982
# 2018-03-31 01:00:00    0.029453    0.084679  ...   0.114982  0.060748
# 2018-03-31 01:00:00    0.084679    0.313792  ...   0.060748  0.060748
#
# [5 rows x 25 columns]

# %% [markdown]
# **Train test Split**

# %%
split_date = '2018-08-30'
ts_train = reframed.loc[reframed.index <= split_date].copy()
ts_test = reframed.loc[reframed.index > split_date].copy()

# %%
train_values = ts_train.values
test_values = ts_test.values
# split into input and outputs
train_X, train_y = train_values[:, :-1], train_values[:, -1]
test_X, test_y = test_values[:, :-1], test_values[:, -1]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (4438, 1, 24) (4438,) (968, 1, 24) (968,)

# %% [markdown]
# # LSTM

# %%
import keras
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import Bidirectional
from tensorflow.keras.utils import to_categorical
from keras.optimizers import SGD 
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
import itertools
from keras.layers import LSTM
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Dropout

# %%
# patient early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

# %% [markdown]
# ## *Vanilla LSTM*

# %%
# https://calvinfeng.gitbook.io/machine-learning-notebook/supervised-learning/recurrent-neural-network/recurrent_neural_networks
model = Sequential()
model.add(LSTM(64, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# fit lstm
history = model.fit(train_X, train_y, epochs=100, batch_size=64, validation_data=(test_X, test_y), verbose=1, shuffle=False, callbacks=[es])
# Out:
# Epoch 1/100
# 70/70 [==============================] - 21s 12ms/step - loss: 0.1028 - val_loss: 0.0302
# Epoch 2/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0293 - val_loss: 0.0200
# Epoch 3/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0211 - val_loss: 0.0154
# Epoch 4/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0173 - val_loss: 0.0130
# Epoch 5/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0148 - val_loss: 0.0112
# Epoch 6/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0129 - val_loss: 0.0099
# Epoch 7/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0118 - val_loss: 0.0089
# Epoch 8/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0107 - val_loss: 0.0086
# Epoch 9/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0099 - val_loss: 0.0082
# Epoch 10/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.0079
# Epoch 11/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0090 - val_loss: 0.0073
# Epoch 12/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0082 - val_loss: 0.0070
# Epoch 13/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0085 - val_loss: 0.0070
# Epoch 14/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0079 - val_loss: 0.0068
# Epoch 15/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0077 - val_loss: 0.0066
# Epoch 16/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0074 - val_loss: 0.0065
# Epoch 17/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0074 - val_loss: 0.0064
# Epoch 18/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0066
# Epoch 19/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0063
# Epoch 20/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0063
# Epoch 21/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 22/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 23/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0061
# Epoch 24/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0060
# Epoch 25/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0061
# Epoch 26/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 27/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.0059
# Epoch 28/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0058
# Epoch 29/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0058
# Epoch 30/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0060
# Epoch 31/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.0057
# Epoch 32/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.0058
# Epoch 33/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0057
# Epoch 34/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 35/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0056
# Epoch 36/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0056
# Epoch 37/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0055
# Epoch 38/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0055
# Epoch 39/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0055
# Epoch 40/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0055
# Epoch 41/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 42/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 43/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 44/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0055
# Epoch 45/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 46/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0055
# Epoch 47/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0054
# Epoch 48/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 49/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0055
# Epoch 50/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0055
# Epoch 51/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 52/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0054
# Epoch 53/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0055
# Epoch 54/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0054
# Epoch 55/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0053
# Epoch 56/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0053
# Epoch 57/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0053
# Epoch 58/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0054
# Epoch 59/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0053
# Epoch 60/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0053
# Epoch 61/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0054
# Epoch 62/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0054
# Epoch 63/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0053
# Epoch 64/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0054
# Epoch 65/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0053
# Epoch 66/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0054
# Epoch 67/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0053
# Epoch 00067: early stopping

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
ts_train_fcst = model.predict(train_X)
ts_test_fcst = model.predict(test_X)
# invert predictions
ts_train_fcst = scaler.inverse_transform(ts_train_fcst)
train_y_i = scaler.inverse_transform([train_y])
ts_test_fcst = scaler.inverse_transform(ts_test_fcst)
test_y_i = scaler.inverse_transform([test_y])

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    """Calculates MAPE given y_true and y_pred"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
print('Train Mean Absolute Error:', mean_absolute_error(train_y_i[0], ts_train_fcst[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(train_y_i[0], ts_train_fcst[:,0])))
print('Test Mean Absolute percentage Error:',mean_absolute_percentage_error(train_y_i[0], ts_train_fcst[:,0]))
print('Test Mean Absolute Error:', mean_absolute_error(test_y_i[0], ts_test_fcst[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(test_y_i[0], ts_test_fcst[:,0])))
print('Test Mean Absolute percentage Error:',mean_absolute_percentage_error(test_y_i[0], ts_test_fcst[:,0]))
# Out:
# Train Mean Absolute Error: 330.43342214873803
# Train Root Mean Squared Error: 465.00705492558853
# Test Mean Absolute percentage Error: 19.091802986832967
# Test Mean Absolute Error: 361.2708156167968
# Test Root Mean Squared Error: 514.3472047279549
# Test Mean Absolute percentage Error: 22.12507715479643

# %%
plt.figure(figsize=(15,6))
plt.plot(ts_test.index, test_y_i[0], marker='o', label="actual")
plt.plot(ts_test.index, ts_test_fcst[:,0], 'r', label="prediction")
plt.ylabel('Traffic Volume', size=15)
plt.xlabel('Date', size=15)
plt.legend(fontsize=13)
plt.show()

# %%
# zoom on lastest week)
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
plt.plot(ts_test.index, test_y_i[0], marker='o', label="actual")
plt.plot(ts_test.index, ts_test_fcst[:,0], 'r', label="prediction")
ax.set_xbound(lower= datetime.date(2018,9,22), upper=datetime.date(2018,9,29))
plt.legend(fontsize=13)
plt.xlabel('Date', size=15)
ax.set_ylim(0, 7000)
plot = plt.suptitle('Lastest week Forecast vs Actuals')

# %% [markdown]
# ## Stacked LSTM

# %%
# https://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/s12911-021-01462-5
model = Sequential()
model.add(LSTM(64, return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(64))
model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# fit LSTM
history = model.fit(train_X, train_y, epochs=100, batch_size=64, validation_data=(test_X, test_y), verbose=1, shuffle=False, callbacks=[es])
# Out:
# Epoch 1/100
# 70/70 [==============================] - 4s 15ms/step - loss: 0.1366 - val_loss: 0.0302
# Epoch 2/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0302 - val_loss: 0.0182
# Epoch 3/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0214 - val_loss: 0.0144
# Epoch 4/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0172 - val_loss: 0.0112
# Epoch 5/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0148 - val_loss: 0.0104
# Epoch 6/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0133 - val_loss: 0.0088
# Epoch 7/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0117 - val_loss: 0.0077
# Epoch 8/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0108 - val_loss: 0.0073
# Epoch 9/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0102 - val_loss: 0.0068
# Epoch 10/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0067
# Epoch 11/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0063
# Epoch 12/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0090 - val_loss: 0.0061
# Epoch 13/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.0060
# Epoch 14/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 0.0059
# Epoch 15/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0077 - val_loss: 0.0058
# Epoch 16/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.0057
# Epoch 17/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0071 - val_loss: 0.0058
# Epoch 18/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 0.0056
# Epoch 19/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0070 - val_loss: 0.0056
# Epoch 20/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0071 - val_loss: 0.0055
# Epoch 21/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0070 - val_loss: 0.0056
# Epoch 22/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0055
# Epoch 23/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 0.0055
# Epoch 24/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 0.0055
# Epoch 25/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 0.0054
# Epoch 26/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.0055
# Epoch 27/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0067 - val_loss: 0.0056
# Epoch 28/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.0055
# Epoch 29/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.0054
# Epoch 30/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.0054
# Epoch 31/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.0055
# Epoch 32/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0055
# Epoch 33/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0054
# Epoch 34/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0053
# Epoch 35/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0058 - val_loss: 0.0054
# Epoch 36/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 0.0054
# Epoch 37/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 38/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0056
# Epoch 39/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 40/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0058 - val_loss: 0.0053
# Epoch 41/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 42/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 43/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 44/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0055
# Epoch 45/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 46/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 47/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 0.0056
# Epoch 48/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0054 - val_loss: 0.0052
# Epoch 49/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 50/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 51/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 52/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 53/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0057
# Epoch 54/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 55/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.0055
# Epoch 56/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0054
# Epoch 57/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0055
# Epoch 58/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 59/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0054
# Epoch 60/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 61/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0053
# Epoch 62/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0052
# Epoch 63/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 64/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.0053
# Epoch 65/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 66/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0053
# Epoch 67/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 68/100
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 69/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 70/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 00070: early stopping

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
ts_train_fcst = model.predict(train_X)
ts_test_fcst = model.predict(test_X)
# invert predictions
ts_train_fcst = scaler.inverse_transform(ts_train_fcst)
train_y_i = scaler.inverse_transform([train_y])
ts_test_fcst = scaler.inverse_transform(ts_test_fcst)
test_y_i = scaler.inverse_transform([test_y])

# %%
print('Train Mean Absolute Error:', mean_absolute_error(train_y_i[0], ts_train_fcst[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(train_y_i[0], ts_train_fcst[:,0])))
print('Test Mean Absolute percentage Error:',mean_absolute_percentage_error(train_y_i[0], ts_train_fcst[:,0]))
print('Test Mean Absolute Error:', mean_absolute_error(test_y_i[0], ts_test_fcst[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(test_y_i[0], ts_test_fcst[:,0])))
print('Test Mean Absolute percentage Error:',mean_absolute_percentage_error(test_y_i[0], ts_test_fcst[:,0]))
# Out:
# Train Mean Absolute Error: 323.9828185407682
# Train Root Mean Squared Error: 452.8450673466948
# Test Mean Absolute percentage Error: 18.41277043613612
# Test Mean Absolute Error: 359.2763202801224
# Test Root Mean Squared Error: 509.66023988160646
# Test Mean Absolute percentage Error: 20.91802500012277

# %%
plt.figure(figsize=(15,6))
plt.plot(ts_test.index, test_y_i[0], marker='o', label="actual")
plt.plot(ts_test.index, ts_test_fcst[:,0], 'r', label="prediction")
plt.ylabel('Traffic Volume', size=15)
plt.xlabel('Date', size=15)
plt.legend(fontsize=13)
plt.show()

# %%
# zoom on lastest week)
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
plt.plot(ts_test.index, test_y_i[0], marker='o', label="actual")
plt.plot(ts_test.index, ts_test_fcst[:,0], 'r', label="prediction")
ax.set_xbound(lower= datetime.date(2018,9,22), upper=datetime.date(2018,9,29))
plt.legend(fontsize=13)
plt.xlabel('Date', size=15)
ax.set_ylim(0, 7000)
plot = plt.suptitle('Lastest week Forecast vs Actuals')

# %% [markdown]
# ## Bidirectional LSTM

# %%
# https://machinelearningmastery.com/develop-bidirectional-lstm-sequence-classification-python-kera
model = Sequential()
model.add(Bidirectional(LSTM(64,activation='relu',), input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# fit LSTM
history = model.fit(train_X, train_y, epochs=100, batch_size=64, validation_data=(test_X, test_y), verbose=1, shuffle=False, callbacks=[es])
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 70/70 [==============================] - 10s 20ms/step - loss: 0.1185 - val_loss: 0.0280
# Epoch 2/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0271 - val_loss: 0.0182
# Epoch 3/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0194 - val_loss: 0.0139
# Epoch 4/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0155 - val_loss: 0.0119
# Epoch 5/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0131 - val_loss: 0.0102
# Epoch 6/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0117 - val_loss: 0.0089
# Epoch 7/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.0109 - val_loss: 0.0085
# Epoch 8/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0101 - val_loss: 0.0074
# Epoch 9/100
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0093 - val_loss: 0.0069
# Epoch 10/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0087 - val_loss: 0.0067
# Epoch 11/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0082 - val_loss: 0.0074
# Epoch 12/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0082 - val_loss: 0.0069
# Epoch 13/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0079 - val_loss: 0.0067
# Epoch 14/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0076 - val_loss: 0.0067
# Epoch 15/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0070 - val_loss: 0.0067
# Epoch 16/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0070 - val_loss: 0.0059
# Epoch 17/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0072 - val_loss: 0.0060
# Epoch 18/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 19/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0069 - val_loss: 0.0060
# Epoch 20/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0066 - val_loss: 0.0057
# Epoch 21/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0054
# Epoch 22/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0059
# Epoch 23/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0059
# Epoch 24/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0062 - val_loss: 0.0061
# Epoch 25/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0061 - val_loss: 0.0055
# Epoch 26/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 27/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0060 - val_loss: 0.0054
# Epoch 28/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 29/100
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0054
# Epoch 30/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.0058 - val_loss: 0.0056
# Epoch 31/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 32/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0058 - val_loss: 0.0051
# Epoch 33/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.0056 - val_loss: 0.0051
# Epoch 34/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 35/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 36/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0056 - val_loss: 0.0058
# Epoch 37/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 38/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 39/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0055
# Epoch 40/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0054
# Epoch 41/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 42/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0054
# Epoch 00042: early stopping

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
ts_train_fcst = model.predict(train_X)
ts_test_fcst = model.predict(test_X)
# invert predictions
ts_train_fcst = scaler.inverse_transform(ts_train_fcst)
train_y_i = scaler.inverse_transform([train_y])
ts_test_fcst = scaler.inverse_transform(ts_test_fcst)
test_y_i = scaler.inverse_transform([test_y])

# %%
print('Train Mean Absolute Error:', mean_absolute_error(train_y_i[0], ts_train_fcst[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(train_y_i[0], ts_train_fcst[:,0])))
print('Test Mean Absolute percentage Error:',mean_absolute_percentage_error(train_y_i[0], ts_train_fcst[:,0]))
print('Test Mean Absolute Error:', mean_absolute_error(test_y_i[0], ts_test_fcst[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(test_y_i[0], ts_test_fcst[:,0])))
print('Test Mean Absolute percentage Error:',mean_absolute_percentage_error(test_y_i[0], ts_test_fcst[:,0]))
# Out:
# Train Mean Absolute Error: 350.886789274624
# Train Root Mean Squared Error: 476.67338569539146
# Test Mean Absolute percentage Error: 22.403960147809286
# Test Mean Absolute Error: 374.6354620752256
# Test Root Mean Squared Error: 517.8723469642551
# Test Mean Absolute percentage Error: 24.660899136690958

# %%
plt.figure(figsize=(15,6))
plt.plot(ts_test.index, test_y_i[0], marker='o', label="actual")
plt.plot(ts_test.index, ts_test_fcst[:,0], 'r', label="prediction")
plt.ylabel('Traffic Volume', size=15)
plt.xlabel('Date', size=15)
plt.legend(fontsize=13)
plt.show()

# %%
# zoom on lastest week)
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
plt.plot(ts_test.index, test_y_i[0], marker='o', label="actual")
plt.plot(ts_test.index, ts_test_fcst[:,0], 'r', label="prediction")
ax.set_xbound(lower= datetime.date(2018,9,22), upper=datetime.date(2018,9,29))
plt.legend(fontsize=13)
plt.xlabel('Date', size=15)
ax.set_ylim(0, 7000)
plot = plt.suptitle('Lastest week Forecast vs Actuals')
